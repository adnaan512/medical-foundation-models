# %% [markdown]
# # Medical Foundation Models - Kaggle Training
#
# This notebook provides an end-to-end example of training the `DINOv2+LoRA` and `EfficientNet-B3` models on the HAM10000 dataset using Kaggle Notebooks.
#
# **Hardware Accelerator:** GPU (P100 or T4x2)
# **Dataset:** Add the HAM10000 dataset to your notebook (`kmader/skin-cancer-mnist-ham10000`)

# %%
# !git clone https://github.com/adnaan512/medical-foundation-models.git
# %cd medical-foundation-models
# !pip install -r requirements.txt

# %% [markdown]
# ## Training DINOv2 + LoRA

# %%
# !python train.py --model dinov2_vitb14 --data_path /kaggle/input/skin-cancer-mnist-ham10000 --batch_size 32 --num_epochs 30

# %% [markdown]
# ## Evaluation

# %%
# !python evaluate.py --model dinov2_vitb14 --checkpoint checkpoints/dinov2_lora_ham10000/best_model.pth --data_path /kaggle/input/skin-cancer-mnist-ham10000 --save_explainability
